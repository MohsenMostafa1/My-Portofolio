# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import tempfile
from six.moves.urllib.request import urlopen
from six import BytesIO
import numpy as np
from PIL import Image
from PIL import ImageColor
from PIL import ImageDraw
from PIL import ImageFont
from PIL import ImageOps
import time
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 2024-06-03 12:52:15.886815: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-03 12:52:15.886921: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-03 12:52:16.041908: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /kaggle/input/vehicle-detection-image-dataset/Sample_Video_HighQuality.mp4
# /kaggle/input/vehicle-detection-image-dataset/SampleVideo_LowQuality.mp4
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_9354_jpg.rf.17a109db9b27f2c8ccf841c86825203d.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_1029_jpg.rf.d578c1ee6bf2ccd09142cb7b273108e9.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_1027_jpg.rf.fa6cad605f1dec6d083e29fd204ebefb.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_7778_jpg.rf.8d35874c3d2b46b2a85283270ff36867.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_3403_jpg.rf.30d0e1ebeda1a2d34985cee7e69fedeb.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_6430_jpg.rf.867b533ae6784572b93d1ff9497f72ce.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_4120_jpg.rf.e9f921269813d1f63bc69970dbc78cd0.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_3423_jpg.rf.a5d9ceb4684e48bcfea110d600d8db93.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_7628_jpg.rf.e7e1807b28d0110e2cd92a44c63f25cd.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_0143_jpg.rf.f11c115e321f53745290e2b2dfcad380.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_7481_jpg.rf.17d485bb3af8bccb03a54196bc9606bf.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_9613_jpg.rf.0552848f846e37a254caeafb236a4180.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_9502_jpg.rf.538bef52263bb0c54d09763b626625f1.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_0911_jpg.rf.f800706c68aaa14bb6a69146facf7e48.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_1321_jpg.rf.51f3321af0e80af53b99a014a20c4771.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_1601_jpg.rf.172e29b3c05c178e3cbd806730dc067d.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_1007_jpg.rf.0cbfce7666ca0c0b40922863f0b9484c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_3616_jpg.rf.a04a48c28060ff70b2ed0d11d3898490.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_1262_jpg.rf.ab5c61dcc95d81ec480d1d64a8b1fb1c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_5218_jpg.rf.14dd3d96e618829a36a4c6309507b5bd.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_8750_jpg.rf.3d74bfdf9ac5ed5f22b6a4f3ab6b9b95.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_1010_jpg.rf.130eb218ff310e902d6f889e3fc756ee.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_1330_jpg.rf.6c68978d8f0e2692073667538d3f0de9.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_1055_jpg.rf.58e1eede072cd8fb7b0902b3ccfc228c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/_annotations.coco.json
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_1002_jpg.rf.2b25d8377146e3cf66aea4b2f3836d2d.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_8186_jpg.rf.7a883db2cddf2636e8edea810bb8db19.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_1028_jpg.rf.e7b9147829b445739ddede0502f15fef.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/valid/frame_4150_jpg.rf.847708b08b9c8ede6f5978a83c6740a6.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_1018_jpg.rf.185b0b25bb53e1d0eb860dda162bb2ae.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_3837_jpg.rf.7cdff66e6350318c835a7cf1b35525f0.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_7020_jpg.rf.2253566dc05fca6e0181a517bab14339.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_9486_jpg.rf.2280c498ddc7234aff225ca73be23450.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_0990_jpg.rf.a3223422e734a57442ee34a58d24d4b4.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_8097_jpg.rf.762bcc82c7b05b2ebcabc219815dca50.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_6406_jpg.rf.ff63b851413c468025e0f9f2dad80fd0.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_7929_jpg.rf.02b89050254d7e4c8c8995125a555cfe.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/_annotations.coco.json
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_4363_jpg.rf.1b2237d870de9cc7618a46bf229d23ed.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_1004_jpg.rf.a6f441255e54620ea11fb3cf34fc0a97.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_1806_jpg.rf.4583992e61114207bd9379b7e0652549.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_9106_jpg.rf.edaac933241f83e08bf00984c0e0c85f.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/test/frame_9055_jpg.rf.067db6b83a7de9859840f6ca2484d373.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1490_jpg.rf.a6446f0b6c4f4ba912d9000c7707dd4f.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_5091_jpg.rf.1be6511c2d2afe908fb143a21c1c4418.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3927_jpg.rf.819c741adb97746069acfce34cb5ee65.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1030_jpg.rf.98527a93c719ca44a6b907071023cb68.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3725_jpg.rf.efc39d949bf15277d421a9945aaece0f.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1683_jpg.rf.2a6e07e81bff1416f72a1504ab55fae0.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1406_jpg.rf.e99483347637e93f2f45e3ac93c00d13.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_0435_jpg.rf.b64a627a937f4b21417074ddc983c184.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1037_jpg.rf.47a32f199219623c5a3aa624b2f57931.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_8649_jpg.rf.2fe2a3f11a3c56eeeaa2f46ec2e5e65c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1000_jpg.rf.c1c8bf4648562d7c6037d773623a449c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_0654_jpg.rf.a078b9fb055bd8aabc4ea0269670ec31.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3390_jpg.rf.0c8f2506e30861bdd7039fadd5159330.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3221_jpg.rf.750002bdd938ae1ca6c71ff7b04d7f4c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1012_jpg.rf.bce319e0a19f6bd51a0bd98ab17192d2.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_4031_jpg.rf.906ca8fac08d4f5b334e15abb7528997.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_4122_jpg.rf.35db1b7385a120b3cd525b90797c7140.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1014_jpg.rf.b18fe8e4cecebd929f94e7f9427da754.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_0002_jpg.rf.a929cd43bfa0953ace4ea9ea00fa9ba7.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_0786_jpg.rf.815a596695f2267e033ce6394667c19d.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_7905_jpg.rf.f31bbd0aa80389fda85eea885d3bb231.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_6869_jpg.rf.49f8ab4faebcc08e893aa78b4c287b5e.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_9130_jpg.rf.43a2d3994183091cf696412eb2483c2e.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_6606_jpg.rf.a08875af2300ee7f2370eccb2591e818.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1250_jpg.rf.86f26eb7d9aefb34d5a289be0ea1852d.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_9797_jpg.rf.853d36698402841e451b411ed4b23a86.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_8432_jpg.rf.949c3e473daf88607b2c05c8008aa628.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1110_jpg.rf.4329d1bcde4d1dda28dd91370ead6f08.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3893_jpg.rf.ce0aa3a33f7dcd3b7792236216192649.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3218_jpg.rf.542dfabd18240a6eae9c2b3407a6a9a0.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_8985_jpg.rf.2ccbfe1b977217a908990a55231e0d98.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3271_jpg.rf.326bb01452f29c1ee0c135eb0c7ecb15.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_6853_jpg.rf.5466f619eee421202b4f8c640bb6d7c8.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1162_jpg.rf.4511843b83eb449d603c08ee7f701a97.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1013_jpg.rf.1683bb60890b228544b67aa990581856.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1006_jpg.rf.1b9373a850a38c393fedb566b102513c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3134_jpg.rf.4ae91b5de3e6a6b0eb64e5f1373751ab.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1616_jpg.rf.312f54b7741ce363a046fd3a6ecdcc34.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_8890_jpg.rf.9fd514e554a1f9d37ff3fe45794a915e.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1011_jpg.rf.4e65c1b7bf83b84f3bbabdcdf9a95f5c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1101_jpg.rf.65117e59addfcc982bdf214fb04b89d5.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1023_jpg.rf.f51a8909e7d6591eb2d2e9ba0b4a4dd8.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_7577_jpg.rf.b839378e81a8d1a875a722718f1105b4.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_7498_jpg.rf.77d305597b10b64c397b93b0762a681c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1558_jpg.rf.074240b145d9e916eab6872205f6f8b1.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1032_jpg.rf.1a346a619957334a2c8ca1a37d55fb3b.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1008_jpg.rf.664e336ac08f9004505f38e94605ff55.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_8179_jpg.rf.0c6d95b0c1e711f3b7a4bf5764617e74.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_8001_jpg.rf.18cdd475220a3add1f2269a5076cba85.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1346_jpg.rf.df598582aabfbab5825068295b807520.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1021_jpg.rf.7e72cd7ed74974dd0921ff9171494662.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_4042_jpg.rf.d81fb40615a71afd3c127ef87eb0bb15.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_8721_jpg.rf.3db9b0731c065dec0e4791a904795444.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1025_jpg.rf.cbac553f21cefa0eea05de2e394702b3.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_9538_jpg.rf.03110592999f1dbf6819eea2a816e9eb.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_4219_jpg.rf.4dde1cb4547756565c65b54917f9c226.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1459_jpg.rf.0f7863db2bcfb4de3165c09b82be0437.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_5968_jpg.rf.0df1e2610361d00c9804ea25b39f36fb.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_8554_jpg.rf.ebbcad315951075b5ac51cad6296ffdb.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1058_jpg.rf.536553c6567d1986a3c67a8f555e9ee7.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1506_jpg.rf.8cdc70857764dbef2f1df557002b50a3.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1003_jpg.rf.9875f8650b93b769ff544d849f453b7c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_4391_jpg.rf.3b179165c9b8e9852698d5f8ca0c93d0.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_2095_jpg.rf.86611090f63ead3a4b6a6756d0389734.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1020_jpg.rf.3544b699f69cedf74a5409a0475fd6ec.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1022_jpg.rf.a312e23f14768f328806aabc24b828b9.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3222_jpg.rf.65be9231ead94e91f763f8a7cc890e1c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1278_jpg.rf.8a8c71e65efe7d5dff46671cdab7568e.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1305_jpg.rf.f744f16a06016952e11b893c38a11731.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_2786_jpg.rf.e5798b7bca539e34a3dc9731b71d0819.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_4298_jpg.rf.52289a1037d7bcb7b5e486dba4d783f1.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_4574_jpg.rf.532ead97a5ef329a662b7a6000fb5dcc.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_5289_jpg.rf.cd71c74f2a6a8e9e18ef319303fe1188.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/_annotations.coco.json
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_8305_jpg.rf.2a4a7cf2ee22258aec4da5cbbe8336c4.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1024_jpg.rf.cd1c83c41c4c68fef48888530ea89a2a.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_0691_jpg.rf.62a645636a577b7dfeb36e12fbba2070.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_9536_jpg.rf.94be4655598489b900b9bb6e6c79db07.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_4817_jpg.rf.2ccb6cd4cf97375b25406c86fafe53aa.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_7192_jpg.rf.2cbd94f19d0ac2936a2e1652c6e9faf0.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_9210_jpg.rf.9cd8cd39e6495b04d1197bce186724d6.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_7314_jpg.rf.cb5f45b2d44c84456e611b75d567ab71.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_7322_jpg.rf.21f3f8fb166caf0b81ac954f3e795622.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3358_jpg.rf.3d6a71074463330aa630f14a585936b3.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1015_jpg.rf.b606346aeeac2ffe72fc0f1d9a954a7f.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_7313_jpg.rf.e093024efeafefd827af3788207eb369.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1016_jpg.rf.b9ff82f84b1b2b26f412bfd05832ee76.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_2128_jpg.rf.67924a7d489dcf777c12f3bb22e5edbc.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1009_jpg.rf.db86a4091bbc3b803203cfaa5775714a.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_0725_jpg.rf.47dda94b1ae3d1c9dac287942b0dba0f.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3414_jpg.rf.e367b44ea7a934f44a79e595e642cd94.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_9065_jpg.rf.0fe652baeea0972ed275d7f0da5e1a3f.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_0087_jpg.rf.6911e25ecb00139750616b606571e714.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_5165_jpg.rf.d5fc5ec64a937e5538b38fa2c22b8bfb.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_4426_jpg.rf.b012e820ab7f08caca56ff32d8dd8d1d.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1001_jpg.rf.d499e6c10b2608d56531ba7694c588ab.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3240_jpg.rf.532e99e60a721e52c744f4f49702fe40.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1370_jpg.rf.d8bc8662cd0b9025c3caacfa655f3134.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_0826_jpg.rf.430664151d4302c34f9cffe920ac34c4.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_3515_jpg.rf.2f8ac6cf97e5b28b1a1561127e443b1c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_0182_jpg.rf.24ccc1dc2e78b06ec38094471560e981.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_1005_jpg.rf.72eca626ce1bf4c1e541ab4a6409f6a9.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.coco/train/frame_9395_jpg.rf.0573d7412696e3e765cbf6c4ba757a7d.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/data.yaml
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_1055_jpg.rf.58e1eede072cd8fb7b0902b3ccfc228c.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_9354_jpg.rf.17a109db9b27f2c8ccf841c86825203d.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_8186_jpg.rf.7a883db2cddf2636e8edea810bb8db19.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_1002_jpg.rf.2b25d8377146e3cf66aea4b2f3836d2d.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_5218_jpg.rf.14dd3d96e618829a36a4c6309507b5bd.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_3616_jpg.rf.a04a48c28060ff70b2ed0d11d3898490.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_4120_jpg.rf.e9f921269813d1f63bc69970dbc78cd0.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_1007_jpg.rf.0cbfce7666ca0c0b40922863f0b9484c.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_4150_jpg.rf.847708b08b9c8ede6f5978a83c6740a6.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_6430_jpg.rf.867b533ae6784572b93d1ff9497f72ce.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_9613_jpg.rf.0552848f846e37a254caeafb236a4180.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_7778_jpg.rf.8d35874c3d2b46b2a85283270ff36867.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_1010_jpg.rf.130eb218ff310e902d6f889e3fc756ee.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_9502_jpg.rf.538bef52263bb0c54d09763b626625f1.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_1027_jpg.rf.fa6cad605f1dec6d083e29fd204ebefb.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_1601_jpg.rf.172e29b3c05c178e3cbd806730dc067d.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_1321_jpg.rf.51f3321af0e80af53b99a014a20c4771.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_1330_jpg.rf.6c68978d8f0e2692073667538d3f0de9.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_1262_jpg.rf.ab5c61dcc95d81ec480d1d64a8b1fb1c.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_7481_jpg.rf.17d485bb3af8bccb03a54196bc9606bf.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_3423_jpg.rf.a5d9ceb4684e48bcfea110d600d8db93.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_1028_jpg.rf.e7b9147829b445739ddede0502f15fef.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_3403_jpg.rf.30d0e1ebeda1a2d34985cee7e69fedeb.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_7628_jpg.rf.e7e1807b28d0110e2cd92a44c63f25cd.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_0143_jpg.rf.f11c115e321f53745290e2b2dfcad380.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_0911_jpg.rf.f800706c68aaa14bb6a69146facf7e48.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_8750_jpg.rf.3d74bfdf9ac5ed5f22b6a4f3ab6b9b95.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/labels/frame_1029_jpg.rf.d578c1ee6bf2ccd09142cb7b273108e9.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_9354_jpg.rf.17a109db9b27f2c8ccf841c86825203d.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_1029_jpg.rf.d578c1ee6bf2ccd09142cb7b273108e9.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_1027_jpg.rf.fa6cad605f1dec6d083e29fd204ebefb.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_7778_jpg.rf.8d35874c3d2b46b2a85283270ff36867.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_3403_jpg.rf.30d0e1ebeda1a2d34985cee7e69fedeb.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_6430_jpg.rf.867b533ae6784572b93d1ff9497f72ce.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_4120_jpg.rf.e9f921269813d1f63bc69970dbc78cd0.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_3423_jpg.rf.a5d9ceb4684e48bcfea110d600d8db93.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_7628_jpg.rf.e7e1807b28d0110e2cd92a44c63f25cd.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_0143_jpg.rf.f11c115e321f53745290e2b2dfcad380.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_7481_jpg.rf.17d485bb3af8bccb03a54196bc9606bf.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_9613_jpg.rf.0552848f846e37a254caeafb236a4180.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_9502_jpg.rf.538bef52263bb0c54d09763b626625f1.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_0911_jpg.rf.f800706c68aaa14bb6a69146facf7e48.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_1321_jpg.rf.51f3321af0e80af53b99a014a20c4771.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_1601_jpg.rf.172e29b3c05c178e3cbd806730dc067d.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_1007_jpg.rf.0cbfce7666ca0c0b40922863f0b9484c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_3616_jpg.rf.a04a48c28060ff70b2ed0d11d3898490.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_1262_jpg.rf.ab5c61dcc95d81ec480d1d64a8b1fb1c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_5218_jpg.rf.14dd3d96e618829a36a4c6309507b5bd.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_8750_jpg.rf.3d74bfdf9ac5ed5f22b6a4f3ab6b9b95.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_1010_jpg.rf.130eb218ff310e902d6f889e3fc756ee.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_1330_jpg.rf.6c68978d8f0e2692073667538d3f0de9.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_1055_jpg.rf.58e1eede072cd8fb7b0902b3ccfc228c.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_1002_jpg.rf.2b25d8377146e3cf66aea4b2f3836d2d.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_8186_jpg.rf.7a883db2cddf2636e8edea810bb8db19.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_1028_jpg.rf.e7b9147829b445739ddede0502f15fef.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/valid/images/frame_4150_jpg.rf.847708b08b9c8ede6f5978a83c6740a6.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_7020_jpg.rf.2253566dc05fca6e0181a517bab14339.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_3837_jpg.rf.7cdff66e6350318c835a7cf1b35525f0.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_9055_jpg.rf.067db6b83a7de9859840f6ca2484d373.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_0990_jpg.rf.a3223422e734a57442ee34a58d24d4b4.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_1018_jpg.rf.185b0b25bb53e1d0eb860dda162bb2ae.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_4363_jpg.rf.1b2237d870de9cc7618a46bf229d23ed.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_1004_jpg.rf.a6f441255e54620ea11fb3cf34fc0a97.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_8097_jpg.rf.762bcc82c7b05b2ebcabc219815dca50.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_1806_jpg.rf.4583992e61114207bd9379b7e0652549.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_9106_jpg.rf.edaac933241f83e08bf00984c0e0c85f.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_9486_jpg.rf.2280c498ddc7234aff225ca73be23450.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_7929_jpg.rf.02b89050254d7e4c8c8995125a555cfe.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/labels/frame_6406_jpg.rf.ff63b851413c468025e0f9f2dad80fd0.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_1018_jpg.rf.185b0b25bb53e1d0eb860dda162bb2ae.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_3837_jpg.rf.7cdff66e6350318c835a7cf1b35525f0.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_7020_jpg.rf.2253566dc05fca6e0181a517bab14339.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_9486_jpg.rf.2280c498ddc7234aff225ca73be23450.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_0990_jpg.rf.a3223422e734a57442ee34a58d24d4b4.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_8097_jpg.rf.762bcc82c7b05b2ebcabc219815dca50.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_6406_jpg.rf.ff63b851413c468025e0f9f2dad80fd0.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_7929_jpg.rf.02b89050254d7e4c8c8995125a555cfe.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_4363_jpg.rf.1b2237d870de9cc7618a46bf229d23ed.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_1004_jpg.rf.a6f441255e54620ea11fb3cf34fc0a97.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_1806_jpg.rf.4583992e61114207bd9379b7e0652549.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_9106_jpg.rf.edaac933241f83e08bf00984c0e0c85f.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/test/images/frame_9055_jpg.rf.067db6b83a7de9859840f6ca2484d373.jpg
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_3271_jpg.rf.326bb01452f29c1ee0c135eb0c7ecb15.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1058_jpg.rf.536553c6567d1986a3c67a8f555e9ee7.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_9065_jpg.rf.0fe652baeea0972ed275d7f0da5e1a3f.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_2095_jpg.rf.86611090f63ead3a4b6a6756d0389734.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_6853_jpg.rf.5466f619eee421202b4f8c640bb6d7c8.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_4042_jpg.rf.d81fb40615a71afd3c127ef87eb0bb15.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_9536_jpg.rf.94be4655598489b900b9bb6e6c79db07.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1006_jpg.rf.1b9373a850a38c393fedb566b102513c.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_9210_jpg.rf.9cd8cd39e6495b04d1197bce186724d6.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_0826_jpg.rf.430664151d4302c34f9cffe920ac34c4.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_3927_jpg.rf.819c741adb97746069acfce34cb5ee65.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1683_jpg.rf.2a6e07e81bff1416f72a1504ab55fae0.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_3515_jpg.rf.2f8ac6cf97e5b28b1a1561127e443b1c.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1022_jpg.rf.a312e23f14768f328806aabc24b828b9.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_6606_jpg.rf.a08875af2300ee7f2370eccb2591e818.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_3218_jpg.rf.542dfabd18240a6eae9c2b3407a6a9a0.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1162_jpg.rf.4511843b83eb449d603c08ee7f701a97.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1558_jpg.rf.074240b145d9e916eab6872205f6f8b1.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_4574_jpg.rf.532ead97a5ef329a662b7a6000fb5dcc.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_0654_jpg.rf.a078b9fb055bd8aabc4ea0269670ec31.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_7192_jpg.rf.2cbd94f19d0ac2936a2e1652c6e9faf0.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1490_jpg.rf.a6446f0b6c4f4ba912d9000c7707dd4f.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_8721_jpg.rf.3db9b0731c065dec0e4791a904795444.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1014_jpg.rf.b18fe8e4cecebd929f94e7f9427da754.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_7313_jpg.rf.e093024efeafefd827af3788207eb369.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_3725_jpg.rf.efc39d949bf15277d421a9945aaece0f.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1406_jpg.rf.e99483347637e93f2f45e3ac93c00d13.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_3893_jpg.rf.ce0aa3a33f7dcd3b7792236216192649.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_4391_jpg.rf.3b179165c9b8e9852698d5f8ca0c93d0.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1008_jpg.rf.664e336ac08f9004505f38e94605ff55.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_8649_jpg.rf.2fe2a3f11a3c56eeeaa2f46ec2e5e65c.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_8179_jpg.rf.0c6d95b0c1e711f3b7a4bf5764617e74.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_0691_jpg.rf.62a645636a577b7dfeb36e12fbba2070.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1009_jpg.rf.db86a4091bbc3b803203cfaa5775714a.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1015_jpg.rf.b606346aeeac2ffe72fc0f1d9a954a7f.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_1024_jpg.rf.cd1c83c41c4c68fef48888530ea89a2a.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_5091_jpg.rf.1be6511c2d2afe908fb143a21c1c4418.txt
# /kaggle/input/vehicle-detection-image-dataset/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov9/train/labels/frame_5968_jpg.rf.0df1e2610361d00c9804ea25b39f36fb.txt
# ...
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1013_jpg.rf.1683bb60890b228544b67aa990581856.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_2095_jpg.rf.71497380b9a2b6a9d5eda3d4448f1d35.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1032_jpg.rf.3af9d1761c6c02738aa3c22bf1830ceb.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_0786_jpg.rf.9c16f9a4a00bb016a85338355e44073d.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_3271_jpg.rf.118321987fc47ca43ceea068df48f2b3.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1006_jpg.rf.1b9373a850a38c393fedb566b102513c.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_3134_jpg.rf.4ae91b5de3e6a6b0eb64e5f1373751ab.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1012_jpg.rf.61cf086e206e44dd1c3c69eb1f488cde.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1616_jpg.rf.312f54b7741ce363a046fd3a6ecdcc34.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_8890_jpg.rf.9fd514e554a1f9d37ff3fe45794a915e.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_3893_jpg.rf.ba61ae77337506b5797a9d3c63715c3f.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_7192_jpg.rf.9c6d8e6aacab0659299ca36ba31b2b6d.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1011_jpg.rf.4e65c1b7bf83b84f3bbabdcdf9a95f5c.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1101_jpg.rf.65117e59addfcc982bdf214fb04b89d5.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1023_jpg.rf.f51a8909e7d6591eb2d2e9ba0b4a4dd8.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_7577_jpg.rf.b839378e81a8d1a875a722718f1105b4.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_7498_jpg.rf.77d305597b10b64c397b93b0762a681c.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1558_jpg.rf.074240b145d9e916eab6872205f6f8b1.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1032_jpg.rf.1a346a619957334a2c8ca1a37d55fb3b.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1008_jpg.rf.664e336ac08f9004505f38e94605ff55.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_0691_jpg.rf.5ccee83c900423ebc9201d81db329e7e.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_8179_jpg.rf.0c6d95b0c1e711f3b7a4bf5764617e74.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_8001_jpg.rf.18cdd475220a3add1f2269a5076cba85.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1346_jpg.rf.df598582aabfbab5825068295b807520.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1021_jpg.rf.7e72cd7ed74974dd0921ff9171494662.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_2786_jpg.rf.1ba0531c485f55277340cfc0e2315223.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_4042_jpg.rf.d81fb40615a71afd3c127ef87eb0bb15.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_8721_jpg.rf.3db9b0731c065dec0e4791a904795444.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1025_jpg.rf.cbac553f21cefa0eea05de2e394702b3.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_9538_jpg.rf.03110592999f1dbf6819eea2a816e9eb.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_4219_jpg.rf.4dde1cb4547756565c65b54917f9c226.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1459_jpg.rf.0f7863db2bcfb4de3165c09b82be0437.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_5968_jpg.rf.0df1e2610361d00c9804ea25b39f36fb.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_8554_jpg.rf.ebbcad315951075b5ac51cad6296ffdb.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1058_jpg.rf.536553c6567d1986a3c67a8f555e9ee7.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1506_jpg.rf.8cdc70857764dbef2f1df557002b50a3.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1003_jpg.rf.9875f8650b93b769ff544d849f453b7c.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1025_jpg.rf.40d00e4d5e810e82cfec925b8a2fe152.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_4391_jpg.rf.3b179165c9b8e9852698d5f8ca0c93d0.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_0435_jpg.rf.2e3980e2d44f690fca901bbe71981b7a.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1506_jpg.rf.d3d2f2154720c9a1d13d70eb43e906f6.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_2095_jpg.rf.86611090f63ead3a4b6a6756d0389734.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1020_jpg.rf.3544b699f69cedf74a5409a0475fd6ec.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1022_jpg.rf.a312e23f14768f328806aabc24b828b9.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_8305_jpg.rf.b90be300d704da262e53cbe57215d7dc.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_4426_jpg.rf.7ee419dc9958fbadd78555c248498c20.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_7498_jpg.rf.198c0497ed35283dce2324bc8aec6251.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_3222_jpg.rf.65be9231ead94e91f763f8a7cc890e1c.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1278_jpg.rf.8a8c71e65efe7d5dff46671cdab7568e.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1305_jpg.rf.f744f16a06016952e11b893c38a11731.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_2786_jpg.rf.e5798b7bca539e34a3dc9731b71d0819.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_4298_jpg.rf.52289a1037d7bcb7b5e486dba4d783f1.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_4574_jpg.rf.532ead97a5ef329a662b7a6000fb5dcc.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_5289_jpg.rf.cd71c74f2a6a8e9e18ef319303fe1188.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_9130_jpg.rf.a1b0f5fbb5200a42349439d198583e07.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_7905_jpg.rf.88c5db6118936edafc07cb71e9110157.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_8305_jpg.rf.2a4a7cf2ee22258aec4da5cbbe8336c4.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1024_jpg.rf.cd1c83c41c4c68fef48888530ea89a2a.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_0691_jpg.rf.62a645636a577b7dfeb36e12fbba2070.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_9536_jpg.rf.94be4655598489b900b9bb6e6c79db07.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1101_jpg.rf.ca6ab8d9578c9c88f5e5c2ff1f41777b.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_4817_jpg.rf.2ccb6cd4cf97375b25406c86fafe53aa.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_7192_jpg.rf.2cbd94f19d0ac2936a2e1652c6e9faf0.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_9210_jpg.rf.9cd8cd39e6495b04d1197bce186724d6.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_7314_jpg.rf.cb5f45b2d44c84456e611b75d567ab71.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_4298_jpg.rf.4b56813c1f8e7feaf7170dee2cbc1204.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_7322_jpg.rf.21f3f8fb166caf0b81ac954f3e795622.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_3358_jpg.rf.3d6a71074463330aa630f14a585936b3.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1015_jpg.rf.b606346aeeac2ffe72fc0f1d9a954a7f.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1110_jpg.rf.015a371ac6969443aa3a7e8a94bbd5e4.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_7313_jpg.rf.e093024efeafefd827af3788207eb369.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_4219_jpg.rf.24a9a8fec976a3a49fb986ef5f884952.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_9538_jpg.rf.9216417e825af5adaee61fef78d0ac65.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1016_jpg.rf.b9ff82f84b1b2b26f412bfd05832ee76.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_2128_jpg.rf.67924a7d489dcf777c12f3bb22e5edbc.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1009_jpg.rf.db86a4091bbc3b803203cfaa5775714a.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_0725_jpg.rf.47dda94b1ae3d1c9dac287942b0dba0f.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_3414_jpg.rf.e367b44ea7a934f44a79e595e642cd94.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_9065_jpg.rf.0fe652baeea0972ed275d7f0da5e1a3f.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_0087_jpg.rf.6911e25ecb00139750616b606571e714.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_5165_jpg.rf.d5fc5ec64a937e5538b38fa2c22b8bfb.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_4426_jpg.rf.b012e820ab7f08caca56ff32d8dd8d1d.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1001_jpg.rf.d499e6c10b2608d56531ba7694c588ab.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_3240_jpg.rf.532e99e60a721e52c744f4f49702fe40.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1370_jpg.rf.d8bc8662cd0b9025c3caacfa655f3134.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_0826_jpg.rf.430664151d4302c34f9cffe920ac34c4.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_3515_jpg.rf.2f8ac6cf97e5b28b1a1561127e443b1c.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_0182_jpg.rf.24ccc1dc2e78b06ec38094471560e981.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_1005_jpg.rf.72eca626ce1bf4c1e541ab4a6409f6a9.jpg
# /kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.yolov9/train/images/frame_9395_jpg.rf.0573d7412696e3e765cbf6c4ba757a7d.jpg

# %%
# Print Tensorflow version
print(tf.__version__)

# Check available GPU devices.
print("The following GPU devices are available: %s" % tf.test.gpu_device_name())
# Out:
# 2.15.0
# The following GPU devices are available: /device:GPU:0

# %%
def display_image(image):
  fig = plt.figure(figsize=(20, 15))
  plt.grid(False)
  plt.imshow(image)


def download_and_resize_image(url, new_width=256, new_height=256,
                              display=False):
  _, filename = tempfile.mkstemp(suffix=".jpg")
  response = urlopen(url)
  image_data = response.read()
  image_data = BytesIO(image_data)
  pil_image = Image.open(image_data)
  pil_image = ImageOps.fit(pil_image, (new_width, new_height), Image.LANCZOS)
  pil_image_rgb = pil_image.convert("RGB")
  pil_image_rgb.save(filename, format="JPEG", quality=90)
  print("Image downloaded to %s." % filename)
  if display:
    display_image(pil_image)
  return filename


def draw_bounding_box_on_image(image,
                               ymin,
                               xmin,
                               ymax,
                               xmax,
                               color,
                               font,
                               thickness=4,
                               display_str_list=()):
  """Adds a bounding box to an image."""
  draw = ImageDraw.Draw(image)
  im_width, im_height = image.size
  (left, right, top, bottom) = (xmin * im_width, xmax * im_width,
                                ymin * im_height, ymax * im_height)
  draw.line([(left, top), (left, bottom), (right, bottom), (right, top),
             (left, top)],
            width=thickness,
            fill=color)

  # If the total height of the display strings added to the top of the bounding
  # box exceeds the top of the image, stack the strings below the bounding box
  # instead of above.
  display_str_heights = [font.getbbox(ds)[3] for ds in display_str_list]
  # Each display_str has a top and bottom margin of 0.05x.
  total_display_str_height = (1 + 2 * 0.05) * sum(display_str_heights)

  if top > total_display_str_height:
    text_bottom = top
  else:
    text_bottom = top + total_display_str_height
  # Reverse list and print from bottom to top.
  for display_str in display_str_list[::-1]:
    bbox = font.getbbox(display_str)
    text_width, text_height = bbox[2], bbox[3]
    margin = np.ceil(0.05 * text_height)
    draw.rectangle([(left, text_bottom - text_height - 2 * margin),
                    (left + text_width, text_bottom)],
                   fill=color)
    draw.text((left + margin, text_bottom - text_height - margin),
              display_str,
              fill="black",
              font=font)
    text_bottom -= text_height - 2 * margin


def draw_boxes(image, boxes, class_names, scores, max_boxes=10, min_score=0.1):
  """Overlay labeled boxes on an image with formatted scores and label names."""
  colors = list(ImageColor.colormap.values())

  try:
    font = ImageFont.truetype("/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf",
                              25)
  except IOError:
    print("Font not found, using default font.")
    font = ImageFont.load_default()

  for i in range(min(boxes.shape[0], max_boxes)):
    if scores[i] >= min_score:
      ymin, xmin, ymax, xmax = tuple(boxes[i])
      display_str = "{}: {}%".format(class_names[i].decode("ascii"),
                                     int(100 * scores[i]))
      color = colors[hash(class_names[i]) % len(colors)]
      image_pil = Image.fromarray(np.uint8(image)).convert("RGB")
      draw_bounding_box_on_image(
          image_pil,
          ymin,
          xmin,
          ymax,
          xmax,
          color,
          font,
          display_str_list=[display_str])
      np.copyto(image, np.array(image_pil))
  return image

# %%
import os
import requests
import tempfile
from PIL import Image

# Download the image.
def download_image(url):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with tempfile.NamedTemporaryFile(suffix=".jpg", delete=False) as temp:
            for chunk in response.iter_content(1024):
                temp.write(chunk)
            return temp.name
    else:
        return None

# %%
def load_image(path):
    return Image.open(path)

# %%
# Download and load the image.
image_path = "/kaggle/input/vehicle-detection-image-dataset/Apply_Grayscale/Apply_Grayscale/Vehicles_Detection.v9i.tensorflow/test/frame_0990_jpg.rf.a3223422e734a57442ee34a58d24d4b4.jpg"
#image_path = download_image(image_url)
#image = load_image(image_path)

# %%
module_handle = "https://tfhub.dev/google/faster_rcnn/openimages_v4/inception_resnet_v2/1" #@param ["https://tfhub.dev/google/openimages_v4/ssd/mobilenet_v2/1", "https://tfhub.dev/google/faster_rcnn/openimages_v4/inception_resnet_v2/1"]

detector = hub.load(module_handle).signatures['default']

# %%
def load_img(path):
  img = tf.io.read_file(path)
  img = tf.image.decode_jpeg(img, channels=3)
  return img

# %%
def run_detector(detector, path):
  img = load_img(path)

  converted_img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]
  start_time = time.time()
  result = detector(converted_img)
  end_time = time.time()

  result = {key:value.numpy() for key,value in result.items()}

  print("Found %d objects." % len(result["detection_scores"]))
  print("Inference time: ", end_time-start_time)

  image_with_boxes = draw_boxes(
      img.numpy(), result["detection_boxes"],
      result["detection_class_entities"], result["detection_scores"])

  display_image(image_with_boxes)

# %%
run_detector(detector, image_path)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1717419246.086741      25 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -2642 } dim { size: -2643 } dim { size: -2644 } dim { size: 1088 } } } inputs { dtype: DT_FLOAT shape { dim { size: -22 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -22 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 17 } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12020" } environment { key: "cudnn" value: "8904" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14626652160 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -22 } dim { size: 17 } dim { size: 17 } dim { size: 1088 } } }
# Found 100 objects.
# Inference time:  51.48251414299011
